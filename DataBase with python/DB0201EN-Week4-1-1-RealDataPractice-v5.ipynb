# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Working with a real world data-set using SQL and Python
#
# Estaimted time needed: **30** minutes
#
# ## Objectives
#
# After complting this lab you will be able to:
#
# *   Understand the dataset for Chicago Public School level performance
# *   Store the dataset in an Db2 database on IBM Cloud instance
# *   Retrieve metadata about tables and columns and query data from mixed case columns
# *   Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01&download=true&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01">link</a>.
#
# **NOTE**:
#
# For the learners who are encountering issues with loading from .csv in DB2 on Firefox, you can download the .txt files and load the data with those: <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.txt?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Store the dataset in a Table
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in the previous lab, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the CHICAGO PUBLIC SCHOOLS dataset and load the dataset into a new table called **SCHOOLS**.
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01"><img src = "https://ibm.box.com/shared/static/uc4xjh1uxcc78ks1i18v668simioz4es.jpg"></a>

# %% [markdown]
# ### Connect to the database
#
# Let us now load the ipython-sql  extension and establish a connection with the database
#
# The following modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you may need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# %sql ibm_db_sa://nhp28028:q8vpTT1chMyN2JVR@21fecfd8-47b7-4937-840d-d791d0218660.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31864/bludb?security=SSL
# Out:
# 'Connected: nhp28028@bludb'

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the SCHOOLS table was created

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql select TABSCHEMA, TABNAME,CREATE_TIME from SYSCAT.TABLES
# Out:
#  * ibm_db_sa://nhp28028:***@21fecfd8-47b7-4937-840d-d791d0218660.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31864/bludb
# Done.
# [('SYSIBM  ', 'SYSTABLES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLUMNS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSVIEWS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSVIEWDEP', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPLAN', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPLANDEP', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECTION', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSTMT', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSDBAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPLANAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTABAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSRELS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINEPARMS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTABCONST', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSKEYCOLUSE', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCHECKS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLCHECKS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSDATATYPES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCONSTDEP', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLDIST', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEVENTMONITORS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEVENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTABLESPACES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSDEPENDENCIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTRIGGERS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSCHEMAAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSCHEMATA', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSUSERAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSNODEGROUPDEF', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSNODEGROUPS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPARTITIONMAPS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSBUFFERPOOLS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSBUFFERPOOLNODES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLPROPERTIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSATTRIBUTES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSHIERARCHIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTBSPACEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSFUNCMAPOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSFUNCMAPPARMOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSFUNCMAPPINGS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXEXPLOITRULES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXEXTENSIONPARMS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXEXTENSIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXEXTENSIONMETHODS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPASSTHRUAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPREDICATESPECS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTYPEMAPPINGS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSERVEROPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSERVERS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTABOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTRANSFORMS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSUSEROPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWRAPOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWRAPPERS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSJARCONTENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSJAROBJECTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSNAMEMAPPINGS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSEQUENCES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXCOLUSE', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSVERSIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLUSE', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSLIBRARIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSLIBRARYBINDFILES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSLIBRARYVERSIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLGROUPS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLGROUPSCOLS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLGROUPDIST', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLGROUPDISTCOUNTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSLIBRARYAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEVENTTABLES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINEPROPERTIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOMMENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSEQUENCEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCODEPROPERTIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXMLSTRINGS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXMLPATHS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXSROBJECTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXSROBJECTCOMPONENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXSROBJECTAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXSROBJECTHIERARCHIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXXMLPATTERNS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXDBMAPGRAPHS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSXDBMAPSHREDTREES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSDATAPARTITIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSDATAPARTITIONEXPRESSION', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSJOBS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTASKS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTUNINGINFO', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYLABELCOMPONENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYLABELCOMPONENTELEMENTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYPOLICIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYPOLICYCOMPONENTRULES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYLABELS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYLABELACCESS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSECURITYPOLICYEXEMPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSURROGATEAUTHIDS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINEOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROUTINEPARMOPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROLES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSROLEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCONTEXTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCONTEXTATTRIBUTES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLLATIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSVARIABLES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSVARIABLEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKLOADS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKLOADCONNATTR', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKLOADAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSERVICECLASSES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKCLASSSETS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKCLASSES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKACTIONSETS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKACTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSTHRESHOLDS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSHISTOGRAMTEMPLATES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSHISTOGRAMTEMPLATEBINS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSHISTOGRAMTEMPLATEUSE', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSAUDITUSE', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSAUDITPOLICIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSMODULEAUTH', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSMODULES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINVALIDOBJECTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSINDEXPARTITIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSPERIODS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCONTROLS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSCOLDEPENDENCIES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSTOGROUPS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSUSAGELISTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSTATEMENTTEXTS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSWORKCLASSATTRIBUTES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSSCPREFTBSPACES', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSUPGRADERUNSTATSTASKS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSAUDITEXCEPTIONS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSMEMBERSUBSETS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSMEMBERSUBSETATTRS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSMEMBERSUBSETMEMBERS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSENVIRONMENT', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEXTTAB', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEXTTABFILEOBJ', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSIBM  ', 'SYSEXTTABCOLS', datetime.datetime(2020, 7, 30, 21, 34, 18, 984976)),
#  ('SYSPUBLIC', 'DUAL', datetime.datetime(2020, 7, 30, 21, 34, 35, 358449)),
#  ('SYSCAT  ', 'SYSCOLPROPERTIES_UNION', datetime.datetime(2022, 7, 25, 19, 10, 50, 803306)),
#  ('SYSIBM  ', 'SYSDUMMY1', datetime.datetime(2020, 7, 30, 21, 34, 35, 722117)),
#  ('SYSCAT  ', 'SYSCOLUMNS_UNION', datetime.datetime(2022, 7, 25, 19, 10, 50, 936082)),
#  ('SYSCAT  ', 'SYSDATATYPES_UNION', datetime.datetime(2022, 7, 25, 19, 10, 50, 968947)),
#  ('SYSCAT  ', 'SYSTABLES_UNION', datetime.datetime(2022, 7, 25, 19, 10, 50, 999065)),
#  ('SYSIBM  ', 'DUAL', datetime.datetime(2022, 7, 25, 19, 10, 51, 82064)),
#  ('SYSIBM  ', 'COLUMNS_S', datetime.datetime(2022, 7, 25, 19, 10, 51, 99025)),
#  ('SYSIBM  ', 'REFERENTIAL_CONSTRAINTS', datetime.datetime(2022, 7, 25, 19, 10, 51, 120281)),
#  ('SYSIBM  ', 'REF_CONSTRAINTS', datetime.datetime(2022, 7, 25, 19, 10, 51, 146327)),
#  ('SYSIBM  ', 'TABLE_CONSTRAINTS', datetime.datetime(2022, 7, 25, 19, 10, 51, 159484)),
#  ('SYSIBM  ', 'TABLES', datetime.datetime(2022, 7, 25, 19, 10, 51, 189500)),
#  ('SYSIBM  ', 'TABLES_S', datetime.datetime(2022, 7, 25, 19, 10, 51, 213724)),
#  ('SYSIBM  ', 'USER_DEFINED_TYPES', datetime.datetime(2022, 7, 25, 19, 10, 51, 228833)),
#  ('SYSIBM  ', 'UDT_S', datetime.datetime(2022, 7, 25, 19, 10, 51, 253483)),
#  ('SYSIBM  ', 'VIEWS', datetime.datetime(2022, 7, 25, 19, 10, 51, 270982)),
#  ('SYSIBM  ', 'PARAMETERS', datetime.datetime(2022, 7, 25, 19, 10, 51, 289330)),
#  ('SYSIBM  ', 'PARAMETERS_S', datetime.datetime(2022, 7, 25, 19, 10, 51, 335500)),
#  ('SYSIBM  ', 'ROUTINES', datetime.datetime(2022, 7, 25, 19, 10, 51, 363426)),
#  ('SYSIBM  ', 'ROUTINES_S', datetime.datetime(2022, 7, 25, 19, 10, 51, 406442)),
#  ('SYSIBM  ', 'SYSFUNCTIONS', datetime.datetime(2022, 7, 25, 19, 10, 51, 432670)),
#  ('SYSIBM  ', 'SYSPROCEDURES', datetime.datetime(2022, 7, 25, 19, 10, 51, 459266)),
#  ('SYSIBM  ', 'SYSFUNCPARMS', datetime.datetime(2022, 7, 25, 19, 10, 51, 475974)),
#  ('SYSIBM  ', 'SYSPROCPARMS', datetime.datetime(2022, 7, 25, 19, 10, 51, 490879)),
#  ('SYSIBM  ', 'SYSREVTYPEMAPPINGS', datetime.datetime(2022, 7, 25, 19, 10, 51, 504590)),
#  ('SYSIBM  ', 'SYSROUTINEPROPERTIESJAVA', datetime.datetime(2022, 7, 25, 19, 10, 51, 548349)),
#  ('SYSCAT  ', 'ATTRIBUTES', datetime.datetime(2022, 7, 25, 19, 10, 51, 568987)),
#  ('SYSCAT  ', 'AUDITPOLICIES', datetime.datetime(2022, 7, 25, 19, 10, 51, 624794)),
#  ('SYSCAT  ', 'AUDITUSE', datetime.datetime(2022, 7, 25, 19, 10, 51, 646606)),
#  ('SYSCAT  ', 'BUFFERPOOLDBPARTITIONS', datetime.datetime(2022, 7, 25, 19, 10, 51, 667386)),
#  ('SYSCAT  ', 'BUFFERPOOLEXCEPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 51, 688096)),
#  ('SYSCAT  ', 'BUFFERPOOLNODES', datetime.datetime(2022, 7, 25, 19, 10, 51, 701223)),
#  ('SYSCAT  ', 'BUFFERPOOLS', datetime.datetime(2022, 7, 25, 19, 10, 51, 722788)),
#  ('SYSCAT  ', 'CASTFUNCTIONS', datetime.datetime(2022, 7, 25, 19, 10, 51, 751525)),
#  ('SYSCAT  ', 'CHECKS', datetime.datetime(2022, 7, 25, 19, 10, 51, 768226)),
#  ('SYSCAT  ', 'COLAUTH', datetime.datetime(2022, 7, 25, 19, 10, 51, 789365)),
#  ('SYSCAT  ', 'COLCHECKS', datetime.datetime(2022, 7, 25, 19, 10, 51, 821818)),
#  ('SYSCAT  ', 'COLDIST', datetime.datetime(2022, 7, 25, 19, 10, 51, 847390)),
#  ('SYSCAT  ', 'COLGROUPCOLS', datetime.datetime(2022, 7, 25, 19, 10, 51, 861739)),
#  ('SYSCAT  ', 'COLGROUPDIST', datetime.datetime(2022, 7, 25, 19, 10, 51, 885493)),
#  ('SYSCAT  ', 'COLGROUPDISTCOUNTS', datetime.datetime(2022, 7, 25, 19, 10, 51, 909171)),
#  ('SYSCAT  ', 'COLGROUPS', datetime.datetime(2022, 7, 25, 19, 10, 51, 929507)),
#  ('SYSCAT  ', 'COLIDENTATTRIBUTES', datetime.datetime(2022, 7, 25, 19, 10, 51, 956248)),
#  ('SYSCAT  ', 'COLLATIONS', datetime.datetime(2022, 7, 25, 19, 10, 51, 985153)),
#  ('SYSCAT  ', 'COLOPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 52, 1766)),
#  ('SYSCAT  ', 'COLUMNS', datetime.datetime(2022, 7, 25, 19, 10, 52, 20702)),
#  ('SYSCAT  ', 'COLUSE', datetime.datetime(2022, 7, 25, 19, 10, 54, 416691)),
#  ('SYSCAT  ', 'CONDITIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 448223)),
#  ('SYSCAT  ', 'CONSTDEP', datetime.datetime(2022, 7, 25, 19, 10, 54, 466666)),
#  ('SYSCAT  ', 'CONTEXTATTRIBUTES', datetime.datetime(2022, 7, 25, 19, 10, 54, 488782)),
#  ('SYSCAT  ', 'CONTEXTS', datetime.datetime(2022, 7, 25, 19, 10, 54, 504470)),
#  ('SYSCAT  ', 'CONTROLDEP', datetime.datetime(2022, 7, 25, 19, 10, 54, 536114)),
#  ('SYSCAT  ', 'CONTROLS', datetime.datetime(2022, 7, 25, 19, 10, 54, 569356)),
#  ('SYSCAT  ', 'DATAPARTITIONEXPRESSION', datetime.datetime(2022, 7, 25, 19, 10, 54, 596361)),
#  ('SYSIBM  ', 'CHECK_CONSTRAINTS', datetime.datetime(2022, 7, 25, 19, 10, 51, 33266)),
#  ('SYSIBM  ', 'COLUMNS', datetime.datetime(2022, 7, 25, 19, 10, 51, 58260)),
#  ('SYSCAT  ', 'EVENTMONITORS', datetime.datetime(2022, 7, 25, 19, 10, 54, 780571)),
#  ('SYSCAT  ', 'EVENTS', datetime.datetime(2022, 7, 25, 19, 10, 54, 794520)),
#  ('SYSCAT  ', 'EVENTTABLES', datetime.datetime(2022, 7, 25, 19, 10, 54, 815791)),
#  ('SYSCAT  ', 'FULLHIERARCHIES', datetime.datetime(2022, 7, 25, 19, 10, 54, 842889)),
#  ('SYSCAT  ', 'FUNCDEP', datetime.datetime(2022, 7, 25, 19, 10, 54, 871019)),
#  ('SYSCAT  ', 'FUNCMAPOPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 887584)),
#  ('SYSCAT  ', 'FUNCMAPPARMOPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 907714)),
#  ('SYSCAT  ', 'FUNCMAPPINGS', datetime.datetime(2022, 7, 25, 19, 10, 54, 929276)),
#  ('SYSCAT  ', 'FUNCPARMS', datetime.datetime(2022, 7, 25, 19, 10, 54, 943039)),
#  ('SYSCAT  ', 'FUNCTIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 957824)),
#  ('SYSCAT  ', 'HIERARCHIES', datetime.datetime(2022, 7, 25, 19, 10, 54, 976946)),
#  ('SYSCAT  ', 'HISTOGRAMTEMPLATEBINS', datetime.datetime(2022, 7, 25, 19, 10, 54, 988439)),
#  ('SYSCAT  ', 'HISTOGRAMTEMPLATES', datetime.datetime(2022, 7, 25, 19, 10, 55, 4232)),
#  ('SYSCAT  ', 'HISTOGRAMTEMPLATEUSE', datetime.datetime(2022, 7, 25, 19, 10, 55, 17964)),
#  ('SYSCAT  ', 'INDEXAUTH', datetime.datetime(2022, 7, 25, 19, 10, 55, 47328)),
#  ('SYSCAT  ', 'INDEXCOLUSE', datetime.datetime(2022, 7, 25, 19, 10, 55, 93292)),
#  ('SYSCAT  ', 'INDEXDEP', datetime.datetime(2022, 7, 25, 19, 10, 55, 128625)),
#  ('SYSCAT  ', 'INDEXES', datetime.datetime(2022, 7, 25, 19, 10, 55, 158159)),
#  ('SYSCAT  ', 'INDEXEXPLOITRULES', datetime.datetime(2022, 7, 25, 19, 10, 55, 241898)),
#  ('SYSCAT  ', 'INDEXEXTENSIONDEP', datetime.datetime(2022, 7, 25, 19, 10, 55, 264857)),
#  ('SYSCAT  ', 'INDEXEXTENSIONMETHODS', datetime.datetime(2022, 7, 25, 19, 10, 55, 284975)),
#  ('SYSCAT  ', 'INDEXEXTENSIONPARMS', datetime.datetime(2022, 7, 25, 19, 10, 55, 308888)),
#  ('SYSCAT  ', 'INDEXEXTENSIONS', datetime.datetime(2022, 7, 25, 19, 10, 55, 330163)),
#  ('SYSCAT  ', 'INDEXOPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 55, 352065)),
#  ('SYSCAT  ', 'INDEXPARTITIONS', datetime.datetime(2022, 7, 25, 19, 10, 55, 371931)),
#  ('SYSCAT  ', 'INDEXXMLPATTERNS', datetime.datetime(2022, 7, 25, 19, 10, 55, 406743)),
#  ('SYSCAT  ', 'INVALIDOBJECTS', datetime.datetime(2022, 7, 25, 19, 10, 55, 439792)),
#  ('SYSCAT  ', 'KEYCOLUSE', datetime.datetime(2022, 7, 25, 19, 10, 55, 458476)),
#  ('SYSCAT  ', 'LIBRARIES', datetime.datetime(2022, 7, 25, 19, 10, 55, 481436)),
#  ('SYSCAT  ', 'LIBRARYAUTH', datetime.datetime(2022, 7, 25, 19, 10, 55, 504431)),
#  ('SYSCAT  ', 'LIBRARYBINDFILES', datetime.datetime(2022, 7, 25, 19, 10, 55, 535096)),
#  ('SYSCAT  ', 'LIBRARYVERSIONS', datetime.datetime(2022, 7, 25, 19, 10, 55, 558049)),
#  ('SYSCAT  ', 'MEMBERSUBSETS', datetime.datetime(2022, 7, 25, 19, 10, 55, 580511)),
#  ('SYSCAT  ', 'MEMBERSUBSETATTRS', datetime.datetime(2022, 7, 25, 19, 10, 55, 595706)),
#  ('SYSCAT  ', 'MEMBERSUBSETMEMBERS', datetime.datetime(2022, 7, 25, 19, 10, 55, 615949)),
#  ('SYSCAT  ', 'MODULEAUTH', datetime.datetime(2022, 7, 25, 19, 10, 55, 649757)),
#  ('SYSCAT  ', 'MODULEOBJECTS', datetime.datetime(2022, 7, 25, 19, 10, 55, 715210)),
#  ('SYSCAT  ', 'MODULES', datetime.datetime(2022, 7, 25, 19, 10, 55, 731893)),
#  ('SYSCAT  ', 'NAMEMAPPINGS', datetime.datetime(2022, 7, 25, 19, 10, 55, 770100)),
#  ('SYSCAT  ', 'NICKNAMES', datetime.datetime(2022, 7, 25, 19, 10, 55, 794185)),
#  ('SYSCAT  ', 'NODEGROUPDEF', datetime.datetime(2022, 7, 25, 19, 10, 55, 828742)),
#  ('SYSCAT  ', 'NODEGROUPS', datetime.datetime(2022, 7, 25, 19, 10, 55, 848284)),
#  ('SYSCAT  ', 'PACKAGEAUTH', datetime.datetime(2022, 7, 25, 19, 10, 55, 863016)),
#  ('SYSCAT  ', 'DATAPARTITIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 619125)),
#  ('SYSCAT  ', 'DATATYPEDEP', datetime.datetime(2022, 7, 25, 19, 10, 54, 651402)),
#  ('SYSCAT  ', 'DATATYPES', datetime.datetime(2022, 7, 25, 19, 10, 54, 671948)),
#  ('SYSCAT  ', 'DBAUTH', datetime.datetime(2022, 7, 25, 19, 10, 54, 693896)),
#  ('SYSCAT  ', 'DBPARTITIONGROUPDEF', datetime.datetime(2022, 7, 25, 19, 10, 54, 710825)),
#  ('SYSCAT  ', 'DBPARTITIONGROUPS', datetime.datetime(2022, 7, 25, 19, 10, 54, 729071)),
#  ('SYSCAT  ', 'EXTERNALTABLEOPTIONS', datetime.datetime(2022, 7, 25, 19, 10, 54, 743095)),
#  ('SYSCAT  ', 'PASSTHRUAUTH', datetime.datetime(2022, 7, 25, 19, 10, 55, 963768)),
#  ('SYSCAT  ', 'PERIODS', datetime.datetime(2022, 7, 25, 19, 10, 55, 997573)),
#  ('SYSCAT  ', 'PREDICATESPECS', datetime.datetime(2022, 7, 25, 19, 10, 56, 19420)),
#  ('SYSCAT  ', 'PROCEDURES', datetime.datetime(2022, 7, 25, 19, 10, 56, 51863)),
#  ('SYSCAT  ', 'PROCPARMS', datetime.datetime(2022, 7, 25, 19, 10, 56, 72156)),
#  ('SYSCAT  ', 'REFERENCES', datetime.datetime(2022, 7, 25, 19, 10, 56, 102798)),
#  ('SYSCAT  ', 'ROLEAUTH', datetime.datetime(2022, 7, 25, 19, 10, 56, 129422)),
#  ('SYSCAT  ', 'ROLES', datetime.datetime(2022, 7, 25, 19, 10, 56, 165551)),
#  ('SYSCAT  ', 'ROUTINEAUTH', datetime.datetime(2022, 7, 25, 19, 11, 3, 313412)),
#  ('SYSCAT  ', 'ROUTINEDEP', datetime.datetime(2022, 7, 25, 19, 11, 3, 340459)),
#  ('SYSCAT  ', 'ROUTINEOPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 3, 388871)),
#  ('SYSCAT  ', 'ROUTINEPARMOPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 3, 404136)),
#  ('SYSCAT  ', 'ROUTINEPARMS', datetime.datetime(2022, 7, 25, 19, 11, 3, 425027)),
#  ('SYSCAT  ', 'ROUTINES', datetime.datetime(2022, 7, 25, 19, 11, 3, 452110)),
#  ('SYSCAT  ', 'ROUTINESFEDERATED', datetime.datetime(2022, 7, 25, 19, 11, 6, 402582)),
#  ('SYSCAT  ', 'ROWFIELDS', datetime.datetime(2022, 7, 25, 19, 11, 6, 416807)),
#  ('SYSCAT  ', 'PACKAGEDEP', datetime.datetime(2022, 7, 25, 19, 10, 55, 891216)),
#  ('SYSCAT  ', 'PACKAGES', datetime.datetime(2022, 7, 25, 19, 10, 55, 919379)),
#  ('SYSCAT  ', 'PARTITIONMAPS', datetime.datetime(2022, 7, 25, 19, 10, 55, 939570)),
#  ('SYSCAT  ', 'USEROPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 13, 3499)),
#  ('SYSCAT  ', 'VARIABLEAUTH', datetime.datetime(2022, 7, 25, 19, 11, 13, 39090)),
#  ('SYSCAT  ', 'VARIABLEDEP', datetime.datetime(2022, 7, 25, 19, 11, 13, 79651)),
#  ('SYSCAT  ', 'VARIABLES', datetime.datetime(2022, 7, 25, 19, 11, 13, 108291)),
#  ('SYSCAT  ', 'VIEWDEP', datetime.datetime(2022, 7, 25, 19, 11, 13, 127442)),
#  ('SYSCAT  ', 'SCHEMAAUTH', datetime.datetime(2022, 7, 25, 19, 11, 6, 432418)),
#  ('SYSCAT  ', 'SCHEMATA', datetime.datetime(2022, 7, 25, 19, 11, 6, 449827)),
#  ('SYSCAT  ', 'SCPREFTBSPACES', datetime.datetime(2022, 7, 25, 19, 11, 6, 478638)),
#  ('SYSCAT  ', 'SECURITYLABELACCESS', datetime.datetime(2022, 7, 25, 19, 11, 6, 504571)),
#  ('SYSCAT  ', 'SECURITYLABELCOMPONENTELEMENTS', datetime.datetime(2022, 7, 25, 19, 11, 6, 538118)),
#  ('SYSCAT  ', 'SECURITYLABELCOMPONENTS', datetime.datetime(2022, 7, 25, 19, 11, 6, 559175)),
#  ('SYSCAT  ', 'SECURITYLABELS', datetime.datetime(2022, 7, 25, 19, 11, 6, 583674)),
#  ('SYSCAT  ', 'SECURITYPOLICIES', datetime.datetime(2022, 7, 25, 19, 11, 6, 600978)),
#  ('SYSCAT  ', 'SECURITYPOLICYCOMPONENTRULES', datetime.datetime(2022, 7, 25, 19, 11, 6, 623433)),
#  ('SYSCAT  ', 'SECURITYPOLICYEXEMPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 6, 643436)),
#  ('SYSCAT  ', 'SEQUENCEAUTH', datetime.datetime(2022, 7, 25, 19, 11, 6, 667028)),
#  ('SYSCAT  ', 'SEQUENCES', datetime.datetime(2022, 7, 25, 19, 11, 6, 707100)),
#  ('SYSCAT  ', 'SERVEROPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 6, 733347)),
#  ('SYSCAT  ', 'SERVERS', datetime.datetime(2022, 7, 25, 19, 11, 6, 761904)),
#  ('SYSCAT  ', 'SERVICECLASSES', datetime.datetime(2022, 7, 25, 19, 11, 6, 779521)),
#  ('SYSCAT  ', 'STATEMENTS', datetime.datetime(2022, 7, 25, 19, 11, 6, 797325)),
#  ('SYSCAT  ', 'STATEMENTTEXTS', datetime.datetime(2022, 7, 25, 19, 11, 6, 814934)),
#  ('SYSCAT  ', 'STOGROUPS', datetime.datetime(2022, 7, 25, 19, 11, 6, 838098)),
#  ('SYSCAT  ', 'SURROGATEAUTHIDS', datetime.datetime(2022, 7, 25, 19, 11, 6, 854256)),
#  ('SYSCAT  ', 'TABAUTH', datetime.datetime(2022, 7, 25, 19, 11, 6, 875401)),
#  ('SYSCAT  ', 'TABCONST', datetime.datetime(2022, 7, 25, 19, 11, 12, 514923)),
#  ('SYSCAT  ', 'TABDEP', datetime.datetime(2022, 7, 25, 19, 11, 12, 534505)),
#  ('SYSCAT  ', 'TABDETACHEDDEP', datetime.datetime(2022, 7, 25, 19, 11, 12, 558179)),
#  ('SYSCAT  ', 'TABLES', datetime.datetime(2022, 7, 25, 19, 11, 12, 575766)),
#  ('SYSCAT  ', 'TABLESPACES', datetime.datetime(2022, 7, 25, 19, 11, 12, 796517)),
#  ('SYSCAT  ', 'TABOPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 12, 815399)),
#  ('SYSCAT  ', 'TBSPACEAUTH', datetime.datetime(2022, 7, 25, 19, 11, 12, 828423)),
#  ('SYSCAT  ', 'THRESHOLDS', datetime.datetime(2022, 7, 25, 19, 11, 12, 861045)),
#  ('SYSCAT  ', 'TRANSFORMS', datetime.datetime(2022, 7, 25, 19, 11, 12, 877811)),
#  ('SYSCAT  ', 'TRIGDEP', datetime.datetime(2022, 7, 25, 19, 11, 12, 892636)),
#  ('SYSCAT  ', 'TRIGGERS', datetime.datetime(2022, 7, 25, 19, 11, 12, 914259)),
#  ('SYSCAT  ', 'TYPEMAPPINGS', datetime.datetime(2022, 7, 25, 19, 11, 12, 963487)),
#  ('SYSCAT  ', 'USAGELISTS', datetime.datetime(2022, 7, 25, 19, 11, 12, 981165)),
#  ('SYSTOOLS', 'POLICY', datetime.datetime(2020, 7, 30, 21, 49, 50, 874086)),
#  ('SYSTOOLS', 'HMON_ATM_INFO', datetime.datetime(2020, 7, 30, 21, 49, 51, 696646)),
#  ('SYSTOOLS', 'HMON_COLLECTION', datetime.datetime(2020, 7, 30, 21, 49, 51, 813766)),
#  ('SYSTOOLS', 'EXPLAIN_INSTANCE', datetime.datetime(2020, 7, 31, 8, 13, 54, 716838)),
#  ('SYSTOOLS', 'EXPLAIN_STATEMENT', datetime.datetime(2020, 7, 31, 8, 13, 54, 791562)),
#  ('SYSTOOLS', 'EXPLAIN_ARGUMENT', datetime.datetime(2020, 7, 31, 8, 13, 54, 893809)),
#  ('SYSTOOLS', 'EXPLAIN_OBJECT', datetime.datetime(2020, 7, 31, 8, 13, 54, 962671)),
#  ('SYSTOOLS', 'EXPLAIN_OPERATOR', datetime.datetime(2020, 7, 31, 8, 13, 55, 3423)),
#  ('SYSTOOLS', 'EXPLAIN_PREDICATE', datetime.datetime(2020, 7, 31, 8, 13, 55, 82038)),
#  ('SYSTOOLS', 'EXPLAIN_STREAM', datetime.datetime(2020, 7, 31, 8, 13, 55, 151462)),
#  ('SYSTOOLS', 'EXPLAIN_DIAGNOSTIC', datetime.datetime(2020, 7, 31, 8, 13, 55, 241810)),
#  ('SYSTOOLS', 'EXPLAIN_DIAGNOSTIC_DATA', datetime.datetime(2020, 7, 31, 8, 13, 55, 346451)),
#  ('SYSTOOLS', 'OBJECT_METRICS', datetime.datetime(2020, 7, 31, 8, 13, 55, 439835)),
#  ('SYSTOOLS', 'ADVISE_INSTANCE', datetime.datetime(2020, 7, 31, 8, 13, 55, 540826)),
#  ('SYSTOOLS', 'ADVISE_INDEX', datetime.datetime(2020, 7, 31, 8, 13, 55, 620066)),
#  ('SYSTOOLS', 'ADVISE_WORKLOAD', datetime.datetime(2020, 7, 31, 8, 13, 55, 682962)),
#  ('SYSTOOLS', 'ADVISE_MQT', datetime.datetime(2020, 7, 31, 8, 13, 55, 737786)),
#  ('SYSTOOLS', 'ADVISE_PARTITION', datetime.datetime(2020, 7, 31, 8, 13, 55, 800259)),
#  ('SYSTOOLS', 'ADVISE_TABLE', datetime.datetime(2020, 7, 31, 8, 13, 55, 869181)),
#  ('SYSTOOLS', 'EXPLAIN_ACTUALS', datetime.datetime(2020, 7, 31, 8, 13, 56, 417227)),
#  ('SYSTOOLS', 'IDAX_MODELS', datetime.datetime(2020, 7, 31, 8, 15, 14, 973241)),
#  ('SYSTOOLS', 'IDAX_COMPONENTS', datetime.datetime(2020, 7, 31, 8, 15, 15, 53306)),
#  ('SYSTOOLS', 'IDAX_PARAMS', datetime.datetime(2020, 7, 31, 8, 15, 15, 134647)),
#  ('SYSTOOLS', 'IDAX_COLPROPS', datetime.datetime(2020, 7, 31, 8, 15, 15, 223892)),
#  ('SYSTOOLS', 'DIST_SPARK', datetime.datetime(2020, 7, 31, 8, 15, 16, 182111)),
#  ('SYSTOOLS', 'LOCAL_SPARK', datetime.datetime(2020, 7, 31, 8, 15, 16, 234714)),
#  ('SYSCAT  ', 'VIEWS', datetime.datetime(2022, 7, 25, 19, 11, 13, 144294)),
#  ('SYSCAT  ', 'WORKACTIONS', datetime.datetime(2022, 7, 25, 19, 11, 13, 162848)),
#  ('SYSCAT  ', 'WORKACTIONSETS', datetime.datetime(2022, 7, 25, 19, 11, 13, 178612)),
#  ('SYSCAT  ', 'WORKCLASSATTRIBUTES', datetime.datetime(2022, 7, 25, 19, 11, 13, 202928)),
#  ('SYSCAT  ', 'WORKCLASSES', datetime.datetime(2022, 7, 25, 19, 11, 13, 216075)),
#  ('SYSCAT  ', 'WORKCLASSSETS', datetime.datetime(2022, 7, 25, 19, 11, 13, 230435)),
#  ('SYSCAT  ', 'WORKLOADAUTH', datetime.datetime(2022, 7, 25, 19, 11, 13, 246595)),
#  ('SYSCAT  ', 'WRAPPERS', datetime.datetime(2022, 7, 25, 19, 11, 13, 311621)),
#  ('SYSCAT  ', 'XDBMAPGRAPHS', datetime.datetime(2022, 7, 25, 19, 11, 13, 331963)),
#  ('SYSCAT  ', 'XDBMAPSHREDTREES', datetime.datetime(2022, 7, 25, 19, 11, 13, 377826)),
#  ('SYSCAT  ', 'XMLSTRINGS', datetime.datetime(2022, 7, 25, 19, 11, 13, 401647)),
#  ('SYSCAT  ', 'XSROBJECTAUTH', datetime.datetime(2022, 7, 25, 19, 11, 13, 415883)),
#  ('SYSCAT  ', 'XSROBJECTCOMPONENTS', datetime.datetime(2022, 7, 25, 19, 11, 13, 453497)),
#  ('SYSCAT  ', 'XSROBJECTDEP', datetime.datetime(2022, 7, 25, 19, 11, 13, 490475)),
#  ('SYSCAT  ', 'XSROBJECTDETAILS', datetime.datetime(2022, 7, 25, 19, 11, 13, 502943)),
#  ('SYSCAT  ', 'XSROBJECTHIERARCHIES', datetime.datetime(2022, 7, 25, 19, 11, 13, 514319)),
#  ('SYSCAT  ', 'XSROBJECTS', datetime.datetime(2022, 7, 25, 19, 11, 13, 527176)),
#  ('SYSSTAT ', 'COLDIST', datetime.datetime(2022, 7, 25, 19, 11, 13, 541612)),
#  ('SYSSTAT ', 'COLGROUPDIST', datetime.datetime(2022, 7, 25, 19, 11, 13, 558890)),
#  ('SYSSTAT ', 'COLGROUPDISTCOUNTS', datetime.datetime(2022, 7, 25, 19, 11, 13, 572099)),
#  ('SYSSTAT ', 'COLGROUPS', datetime.datetime(2022, 7, 25, 19, 11, 13, 586320)),
#  ('SYSSTAT ', 'COLUMNS', datetime.datetime(2022, 7, 25, 19, 11, 13, 600230)),
#  ('SYSSTAT ', 'FUNCTIONS', datetime.datetime(2022, 7, 25, 19, 11, 13, 624816)),
#  ('SYSSTAT ', 'INDEXES', datetime.datetime(2022, 7, 25, 19, 11, 13, 641381)),
#  ('SYSSTAT ', 'ROUTINES', datetime.datetime(2022, 7, 25, 19, 11, 13, 666586)),
#  ('SYSSTAT ', 'TABLES', datetime.datetime(2022, 7, 25, 19, 11, 13, 680747)),
#  ('SYSIBM  ', 'SQLCOLPRIVILEGES', datetime.datetime(2022, 7, 25, 19, 11, 25, 796710)),
#  ('SYSIBM  ', 'SQLCOLUMNS', datetime.datetime(2022, 7, 25, 19, 11, 25, 837672)),
#  ('SYSIBM  ', 'SQLFOREIGNKEYS', datetime.datetime(2022, 7, 25, 19, 11, 25, 896224)),
#  ('SYSCAT  ', 'WORKLOADCONNATTR', datetime.datetime(2022, 7, 25, 19, 11, 13, 264146)),
#  ('SYSCAT  ', 'WORKLOADS', datetime.datetime(2022, 7, 25, 19, 11, 13, 278370)),
#  ('SYSCAT  ', 'WRAPOPTIONS', datetime.datetime(2022, 7, 25, 19, 11, 13, 293779)),
#  ('SYSIBMADM', 'SNAPDBM_MEMORY_POOL', datetime.datetime(2022, 7, 25, 19, 11, 26, 315695)),
#  ('SYSIBMADM', 'SNAPDETAILLOG', datetime.datetime(2022, 7, 25, 19, 11, 26, 330111)),
#  ('SYSIBMADM', 'SNAPDYN_SQL', datetime.datetime(2022, 7, 25, 19, 11, 26, 345099)),
#  ('SYSIBMADM', 'SNAPFCM', datetime.datetime(2022, 7, 25, 19, 11, 26, 364581)),
#  ('SYSIBMADM', 'SNAPFCM_PART', datetime.datetime(2022, 7, 25, 19, 11, 26, 381267)),
#  ('SYSIBMADM', 'SNAPHADR', datetime.datetime(2022, 7, 25, 19, 11, 26, 396833)),
#  ('SYSIBMADM', 'SNAPLOCK', datetime.datetime(2022, 7, 25, 19, 11, 26, 411714)),
#  ('SYSIBMADM', 'SNAPLOCKWAIT', datetime.datetime(2022, 7, 25, 19, 11, 26, 429389)),
#  ('SYSIBMADM', 'SNAPSTMT', datetime.datetime(2022, 7, 25, 19, 11, 26, 451050)),
#  ('SYSIBMADM', 'SNAPSTORAGE_PATHS', datetime.datetime(2022, 7, 25, 19, 11, 26, 473345)),
#  ('SYSIBMADM', 'SNAPSUBSECTION', datetime.datetime(2022, 7, 25, 19, 11, 26, 491132)),
#  ('SYSIBMADM', 'SNAPSWITCHES', datetime.datetime(2022, 7, 25, 19, 11, 26, 507415)),
#  ('SYSIBMADM', 'SNAPTAB_REORG', datetime.datetime(2022, 7, 25, 19, 11, 26, 521984)),
#  ('SYSIBMADM', 'SNAPTAB', datetime.datetime(2022, 7, 25, 19, 11, 26, 538246)),
#  ('SYSIBMADM', 'SNAPTBSP', datetime.datetime(2022, 7, 25, 19, 11, 26, 558134)),
#  ('SYSIBMADM', 'SNAPTBSP_PART', datetime.datetime(2022, 7, 25, 19, 11, 26, 579696)),
#  ('SYSIBMADM', 'SNAPTBSP_QUIESCER', datetime.datetime(2022, 7, 25, 19, 11, 26, 596774)),
#  ('SYSIBMADM', 'SNAPTBSP_RANGE', datetime.datetime(2022, 7, 25, 19, 11, 26, 613822)),
#  ('SYSIBMADM', 'SNAPUTIL', datetime.datetime(2022, 7, 25, 19, 11, 26, 632565)),
#  ('SYSIBMADM', 'SNAPUTIL_PROGRESS', datetime.datetime(2022, 7, 25, 19, 11, 26, 648029)),
#  ('SYSIBMADM', 'REG_VARIABLES', datetime.datetime(2022, 7, 25, 19, 11, 26, 662345)),
#  ('SYSIBMADM', 'ENV_SYS_INFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 675923)),
#  ('SYSIBM  ', 'SQLPRIMARYKEYS', datetime.datetime(2022, 7, 25, 19, 11, 25, 913967)),
#  ('SYSIBM  ', 'SQLPROCEDURECOLS', datetime.datetime(2022, 7, 25, 19, 11, 25, 926035)),
#  ('SYSIBM  ', 'SQLPROCEDURES', datetime.datetime(2022, 7, 25, 19, 11, 25, 949147)),
#  ('SYSIBM  ', 'SQLSPECIALCOLUMNS', datetime.datetime(2022, 7, 25, 19, 11, 25, 962527)),
#  ('SYSIBM  ', 'SQLSTATISTICS', datetime.datetime(2022, 7, 25, 19, 11, 25, 980542)),
#  ('SYSIBM  ', 'SQLTABLEPRIVILEGES', datetime.datetime(2022, 7, 25, 19, 11, 25, 998227)),
#  ('SYSIBM  ', 'SQLTABLETYPES', datetime.datetime(2022, 7, 25, 19, 11, 26, 28550)),
#  ('SYSIBM  ', 'SQLSCHEMAS', datetime.datetime(2022, 7, 25, 19, 11, 26, 40302)),
#  ('SYSIBM  ', 'SQLTABLES', datetime.datetime(2022, 7, 25, 19, 11, 26, 49558)),
#  ('SYSIBM  ', 'SQLUDTS', datetime.datetime(2022, 7, 25, 19, 11, 26, 57454)),
#  ('SYSIBM  ', 'SQLTYPEINFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 71561)),
#  ('SYSIBMADM', 'SNAPAGENT', datetime.datetime(2022, 7, 25, 19, 11, 26, 88498)),
#  ('SYSIBMADM', 'SNAPAGENT_MEMORY_POOL', datetime.datetime(2022, 7, 25, 19, 11, 26, 112260)),
#  ('SYSIBMADM', 'SNAPAPPL', datetime.datetime(2022, 7, 25, 19, 11, 26, 131287)),
#  ('SYSIBMADM', 'SNAPAPPL_INFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 166175)),
#  ('SYSIBMADM', 'SNAPBP', datetime.datetime(2022, 7, 25, 19, 11, 26, 194482)),
#  ('SYSIBMADM', 'SNAPBP_PART', datetime.datetime(2022, 7, 25, 19, 11, 26, 218433)),
#  ('SYSIBMADM', 'SNAPCONTAINER', datetime.datetime(2022, 7, 25, 19, 11, 26, 232581)),
#  ('SYSIBMADM', 'SNAPDB', datetime.datetime(2022, 7, 25, 19, 11, 26, 254236)),
#  ('SYSIBMADM', 'SNAPDB_MEMORY_POOL', datetime.datetime(2022, 7, 25, 19, 11, 26, 283512)),
#  ('SYSIBMADM', 'SNAPDBM', datetime.datetime(2022, 7, 25, 19, 11, 26, 300713)),
#  ('SYSIBMADM', 'LOCKWAITS', datetime.datetime(2022, 7, 25, 19, 11, 27, 243357)),
#  ('SYSIBMADM', 'LOG_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 27, 258132)),
#  ('SYSIBMADM', 'LONG_RUNNING_SQL', datetime.datetime(2022, 7, 25, 19, 11, 27, 277787)),
#  ('SYSIBMADM', 'QUERY_PREP_COST', datetime.datetime(2022, 7, 25, 19, 11, 27, 300255)),
#  ('SYSIBMADM', 'TBSP_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 27, 317262)),
#  ('SYSIBMADM', 'TOP_DYNAMIC_SQL', datetime.datetime(2022, 7, 25, 19, 11, 27, 334714)),
#  ('SYSIBMADM', 'MON_BP_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 29, 75445)),
#  ('SYSIBMADM', 'MON_TBSP_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 29, 95775)),
#  ('SYSIBMADM', 'MON_PKG_CACHE_SUMMARY', datetime.datetime(2022, 7, 25, 19, 11, 29, 119017)),
#  ('SYSIBMADM', 'MON_CURRENT_SQL', datetime.datetime(2022, 7, 25, 19, 11, 29, 137737)),
#  ('SYSIBMADM', 'MON_CURRENT_UOW', datetime.datetime(2022, 7, 25, 19, 11, 29, 166271)),
#  ('SYSIBMADM', 'MON_SERVICE_SUBCLASS_SUMMARY', datetime.datetime(2022, 7, 25, 19, 11, 29, 192575)),
#  ('SYSIBMADM', 'MON_WORKLOAD_SUMMARY', datetime.datetime(2022, 7, 25, 19, 11, 29, 218139)),
#  ('SYSIBMADM', 'MON_CONNECTION_SUMMARY', datetime.datetime(2022, 7, 25, 19, 11, 29, 242345)),
#  ('SYSIBMADM', 'ENV_PROD_INFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 689107)),
#  ('SYSIBMADM', 'ENV_INST_INFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 703626)),
#  ('SYSIBMADM', 'ENV_FEATURE_INFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 718491)),
#  ('SYSIBMADM', 'DB_HISTORY', datetime.datetime(2022, 7, 25, 19, 11, 26, 733378)),
#  ('SYSIBMADM', 'PDLOGMSGS_LAST24HOURS', datetime.datetime(2022, 7, 25, 19, 11, 26, 748594)),
#  ('SYSIBMADM', 'AUTHORIZATIONIDS', datetime.datetime(2022, 7, 25, 19, 11, 26, 794271)),
#  ('SYSIBMADM', 'PRIVILEGES', datetime.datetime(2022, 7, 25, 19, 11, 26, 835597)),
#  ('SYSIBMADM', 'OBJECTOWNERS', datetime.datetime(2022, 7, 25, 19, 11, 26, 867373)),
#  ('SYSIBMADM', 'ADMINTABINFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 905918)),
#  ('SYSIBMADM', 'ADMINTABCOMPRESSINFO', datetime.datetime(2022, 7, 25, 19, 11, 26, 936938)),
#  ('SYSIBMADM', 'NOTIFICATIONLIST', datetime.datetime(2022, 7, 25, 19, 11, 26, 951657)),
#  ('SYSIBMADM', 'CONTACTGROUPS', datetime.datetime(2022, 7, 25, 19, 11, 26, 967402)),
#  ('SYSIBMADM', 'CONTACTS', datetime.datetime(2022, 7, 25, 19, 11, 26, 981292)),
#  ('SYSIBMADM', 'DBCFG', datetime.datetime(2022, 7, 25, 19, 11, 26, 995884)),
#  ('SYSIBMADM', 'DBMCFG', datetime.datetime(2022, 7, 25, 19, 11, 27, 59184)),
#  ('SYSIBMADM', 'DBPATHS', datetime.datetime(2022, 7, 25, 19, 11, 27, 86138)),
#  ('SYSIBMADM', 'APPLICATIONS', datetime.datetime(2022, 7, 25, 19, 11, 27, 105521)),
#  ('SYSIBMADM', 'APPL_PERFORMANCE', datetime.datetime(2022, 7, 25, 19, 11, 27, 125101)),
#  ('SYSIBMADM', 'BP_HITRATIO', datetime.datetime(2022, 7, 25, 19, 11, 27, 173881)),
#  ('SYSIBMADM', 'BP_READ_IO', datetime.datetime(2022, 7, 25, 19, 11, 27, 188864)),
#  ('SYSIBMADM', 'BP_WRITE_IO', datetime.datetime(2022, 7, 25, 19, 11, 27, 202663)),
#  ('SYSIBMADM', 'CONTAINER_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 27, 215490)),
#  ('SYSIBMADM', 'LOCKS_HELD', datetime.datetime(2022, 7, 25, 19, 11, 27, 229286)),
#  ('SYSIBMADM', 'MON_DB_SUMMARY', datetime.datetime(2022, 7, 25, 19, 11, 29, 267053)),
#  ('SYSIBMADM', 'ENV_SYS_RESOURCES', datetime.datetime(2022, 7, 25, 19, 11, 29, 288578)),
#  ('SYSIBMADM', 'ADMINTEMPTABLES', datetime.datetime(2022, 7, 25, 19, 11, 29, 301267)),
#  ('SYSIBMADM', 'ADMINTEMPCOLUMNS', datetime.datetime(2022, 7, 25, 19, 11, 29, 317509)),
#  ('SYSIBMADM', 'MON_LOCKWAITS', datetime.datetime(2022, 7, 25, 19, 11, 29, 338142)),
#  ('SYSIBMADM', 'ENV_CF_SYS_RESOURCES', datetime.datetime(2022, 7, 25, 19, 11, 29, 375011)),
#  ('SYSIBMADM', 'DB2_CLUSTER_HOST_STATE', datetime.datetime(2022, 7, 25, 19, 11, 29, 389520)),
#  ('SYSIBMADM', 'DB2_CF', datetime.datetime(2022, 7, 25, 19, 11, 29, 403507)),
#  ('SYSIBMADM', 'DB2_MEMBER', datetime.datetime(2022, 7, 25, 19, 11, 29, 417124)),
#  ('SYSIBMADM', 'DB2_INSTANCE_ALERTS', datetime.datetime(2022, 7, 25, 19, 11, 29, 430233)),
#  ('SYSIBMADM', 'MON_TRANSACTION_LOG_UTILIZATION', datetime.datetime(2022, 7, 25, 19, 11, 29, 443880)),
#  ('SYSIBMADM', 'INGEST_USER_CONNECTIONS', datetime.datetime(2022, 7, 25, 19, 11, 29, 458402)),
#  ('SYSTOOLS', 'ADMINTASKS', datetime.datetime(2021, 10, 12, 14, 56, 55, 343739)),
#  ('SYSTOOLS', 'ADMINTASKSTATUS', datetime.datetime(2021, 10, 12, 14, 56, 55, 445179)),
#  ('SYSTOOLS', 'ADMIN_TASK_LIST', datetime.datetime(2021, 10, 12, 14, 56, 55, 510028)),
#  ('SYSTOOLS', 'ADMIN_TASK_STATUS', datetime.datetime(2021, 10, 12, 14, 56, 55, 523409)),
#  ('NHP28028', 'ADMIN', datetime.datetime(2022, 7, 14, 5, 35, 48, 313303)),
#  ('NHP28028', 'USER', datetime.datetime(2022, 7, 14, 5, 36, 49, 490882)),
#  ('NHP28028', 'INSTRUCTOR', datetime.datetime(2022, 7, 15, 7, 16, 18, 236250)),
#  ('SYSTOOLS', 'STMG_DBSIZE_INFO', datetime.datetime(2021, 7, 12, 14, 4, 58, 457818)),
#  ('SYSTOOLS', 'MESSAGES', datetime.datetime(2021, 6, 17, 19, 4, 23, 327059))]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.TABLES contains the table metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA='YOUR-DB2-USERNAME'
#
# or, you can retrieve list of all tables where the schema name is not one of the system created ones:
#
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
#       where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
#
# or, just query for a specifc table that you want to verify exists in the database
# %sql select * from SYSCAT.TABLES where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# In Db2 the system catalog table called SYSCAT.COLUMNS contains the column metadata
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# Now retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length.

# %%
# type in your query to retrieve all column names in the SCHOOLS table along with their datatypes and length

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'SCHOOLS'
#
# or
#
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'SCHOOLS'
#
# -->

# %% [markdown]
# ### Questions
#
# 1.  Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
# 2.  What is the name of "Community Area Name" column in your table? Does it have spaces?
# 3.  Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "\_"?

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Which column specifies the school type e.g. 'ES', 'MS', 'HS'? ("Elementary School, Middle School, High School")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Does the column name have mixed case, spaces or other special characters?
# If so, ensure you use double quotes around the "Name of the Column"
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select count(*) from SCHOOLS where "Elementary, Middle, or High School" = 'ES'
#
# Correct answer: 462
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the MAX() function
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
#
# Correct answer: 99
# -->

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# In the previous problem we found out that the highest Safety Score is 99, so we can use that as an input in the where clause:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where Safety_Score = 99
#
# or, a better way:
#
# %sql select Name_of_School, Safety_Score from SCHOOLS where \
#   Safety_Score= (select MAX(Safety_Score) from SCHOOLS)
#
#
# Correct answer: several schools with with Safety Score of 99.
# -->

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Name_of_School, Average_Student_Attendance from SCHOOLS \
#     order by Average_Student_Attendance desc nulls last limit 10
#
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Use the REPLACE() function to replace '%' with ''
# See documentation for this function at:
# https://www.ibm.com/support/knowledgecenter/en/SSEPGG_10.5.0/com.ibm.db2.luw.sql.ref.doc/doc/r0000843.html
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Hint:
#
# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
#      from SCHOOLS \
#      order by Average_Student_Attendance \
#      fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# The datatype of the "Average_Student_Attendance" column is varchar.
# So you cannot use it as is in the where clause for a numeric comparison.
# First use the CAST() function to cast it as a DECIMAL or DOUBLE
# e.g. CAST("Column_Name" as DOUBLE)
# or simply: DECIMAL("Column_Name")
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget the '%' age sign needs to be removed before casting
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
#      order by Average_Student_Attendance
#
# or,
#
# %sql SELECT Name_of_School, Average_Student_Attendance  \
#      from SCHOOLS \
#      where DECIMAL ( REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
#      order by Average_Student_Attendance
#
# -->

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Verify the exact name of the Enrollment column in the database
# Use the SUM() function to add up the Enrollments for each Community Area
# -->

# %% [markdown]
# Double-click **here** for another hint
#
# <!--
# Don't forget to group by the Community Area
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name
#
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Order the previous query and limit the number of rows you fetch
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
#    from SCHOOLS \
#    group by Community_Area_Name \
#    order by TOTAL_ENROLLMENT asc \
#    fetch first 5 rows only
#
# -->

# %% [markdown]
# ### Problem 10
#
# ##### List 5 schools with lowest safety score.

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
#
# %sql SELECT name_of_school, safety_score \
# FROM schools \
# ORDER BY safety_score \
# LIMIT 5
# -->

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has College Enrollment of 4368

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %%sql
# select hardship_index
#    from chicago_socioeconomic_data CD, schools CPS
#    where CD.ca = CPS.community_area_number
#       and college_enrollment = 4368
#
# -->

# %% [markdown]
# ### Problem 12
#
# ##### Get the hardship index for the community area which has the school with the  highest enrollment.

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- Solution:
# NOTE: For this solution to work the CHICAGO_SOCIOECONOMIC_DATA table
#       as created in the last lab of Week 3 should already exist
#
# %sql select ca, community_area_name, hardship_index from chicago_socioeconomic_data \
#    where ca in \
#    ( select community_area_number from schools order by college_enrollment desc limit 1 )
#
# -->

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01" target="_blank">Rav Ahuja</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                        |
# | ----------------- | ------- | ----------------- | ----------------------------------------- |
# | 2021-07-09        | 2.4     | Malika            | Updated connection string                 |
# | 2021-05-19        | 2.3     | Lakshmi Holla     | Updated question                          |
# | 2021-04-20        | 2.2     | Malika            | Added the libraries                       |
# | 2020-11-27        | 2.1     | Sannareddy Ramesh | Modified data sets and added new problems |
# | 2020-08-28        | 2.0     | Lavanya           | Moved lab to course repo in GitLab        |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
